# %%
function rand_dx(x)
    rn = rand()
    breaks = [1/x: 01/x: 1;]
    for (index, break_) in enumerate(breaks)
        if rn < break_
            return index
        end
    end
end
 
function rand_ydx(y, x)
    return_list = ones(Int64(y))
    for (index, element) in enumerate(return_list)
        damage_roll = rand_dx(x)
        return_list[index] = damage_roll
    end
    sum_rolls = sum(return_list)
    return sum(return_list)
end
 
function rand_smite(y, x)
    return_list = ones(Int64(y))
    for (index, element) in enumerate(return_list)
        return_list[index] = x
    end
    return sum(return_list)
end
 
function sum_roll(to_hit, to_avoid)
    roll_hit=rand_dx(20)
    roll_avoid=rand_dx(20)
    sum_roll = (roll_hit+to_hit) - (roll_avoid+to_avoid)
    return sum_roll
end
 
function one_hit(to_hit, to_avoid, weight, balanced)
    
    sumroll = sum_roll(to_hit, to_avoid)
    
    if sumroll<0 && balanced==false
        bonus_dice=-1
    elseif sumroll<0 && balanced==true
        sumroll = sum_roll(to_hit, to_avoid)
        if sumroll<=0
            bonus_dice=-1
        else
            bonus_dice = floor(sumroll/(7+weight))
        end
    else
        bonus_dice = floor(sumroll/(7+weight))
    end
    return bonus_dice
end
 
function one_round(to_hit, to_avoid, weight, dice, damage, armour, smite, balanced)
    bonus_dice = one_hit(to_hit, to_avoid, weight, balanced)
 
    if bonus_dice >= 0 && smite == false
        total_damage = rand_ydx((dice+bonus_dice), damage)
    elseif bonus_dice >=0 && smite == true
        total_damage = rand_smite((dice+bonus_dice), damage)
    else
        total_damage = 0
    end
    total_damage = max(total_damage, 0)
    total_damage = total_damage-armour
    total_damage = max(total_damage, 0)
    return total_damage, bonus_dice
end

function calculate_hp(constitution)
    hp = floor(20*(1.2)^constitution)
    return hp
end

function function_belegwath(field)
    if field == "health"
        return rand_ydx(36,4)
    elseif field == "to_avoid"
        return 17
    elseif field == "armour"
        return rand_ydx(4, 4)
    elseif field == "attack"
        if rand()<0.5
            to_hit_enemy = 22
            enemy_dice = 3
            enemy_damage_total = 14
        else
            to_hit_enemy = 18
            enemy_dice = 3
            enemy_damage_total = 8
        end
        return to_hit_enemy, enemy_dice, enemy_damage_total
    elseif field == "name"
        return "Belegwath, Balrog of Shadow"
    end
end

function my_armour(field)
    if field == "armour"
        return rand_ydx(1,7)+rand_ydx(1,3)+rand_ydx(1,2)+1
    elseif field == "to_avoid"
        return (-1+2-2)
    end
end

function great_sword(field)
    if field=="to_avoid"
        return 1
    elseif field=="to_hit"
        return -1
    elseif field=="weapon_weigh"
        return 6
    elseif field=="weapon_dice"
        return 3
    elseif field=="weapon_damage"
        return 5
    end
end
    
 
function one_fight(constitution,
                   melee,
                   evasion,
                   function_weapon,
                   strength,
                   concentration,
                   perception_concentration,
                   finess,
                   power,
                   subtlety,
                   smite,
                   balanced,
                   function_my_armour,
                   function_enemy)
    
    my_name = "Antar"

    to_hit_mine=melee+function_weapon("to_hit")
    to_avoid_mine=evasion+function_weapon("to_avoid")+function_my_armour("to_avoid")

    health_mine = calculate_hp(constitution)

    weapon_dice=function_weapon("weapon_dice")
    weapon_weight=function_weapon("weapon_weigh")
    weapon_damage=function_weapon("weapon_damage")
    
    if finess==true
        weapon_weight=weapon_weight-2
    end
    if (finess==true && subtlety==true)
        weapon_weight=weapon_weight-2
    end

    if power==true
        weapon_weight=weapon_weight+1
        strength=strength+1
    end

    health_enemy = function_enemy("health")
    to_avoid_enemy = function_enemy("to_avoid")
    enemy_name = function_enemy("name")
    
    round = 0
    max_concentration = floor(perception_concentration/2)

    while true
        if concentration==true
            concentration_bonus=min(round, max_concentration)
        else
            concentration_bonus=0
        end

        armour_mine = function_my_armour("armour")
        armour_enemy = function_enemy("armour")

        weapon_damage_total = min(strength, weapon_weight)+weapon_damage
        
        (my_hit, bonus_dice) = one_round(to_hit_mine+concentration_bonus,
                           to_avoid_enemy,
                           weapon_weight,
                           weapon_dice,
                           weapon_damage_total,
                           armour_enemy,
                           smite,
                           balanced)
 
        
        crit_exclamations = "!"^Int64(max(bonus_dice, 0))
        
        health_enemy = health_enemy-my_hit
        println("$my_name hit $enemy_name for $my_hit damage$crit_exclamations  left $health_enemy  enemy HP")
        if health_enemy<=0
            println("$my_name wins!")
            return 1
        end      
 
        if smite==true
            num_turn=2
        else
            num_turn=1
        end

        for _ in 1:num_turn
            to_hit_enemy, enemy_dice, enemy_damage_total = function_enemy("attack")
            
            (enemy_hit, bonus_dice) = one_round(to_hit_enemy,
                                  to_avoid_mine,
                                  0,
                                  enemy_dice,
                                  enemy_damage_total,
                                  armour_mine,
                                  false,
                                  false)

            crit_exclamations = "!"^Int64(max(bonus_dice, 0))

            
            health_mine = health_mine-enemy_hit
            println("$enemy_name hit $my_name for $enemy_hit damage$crit_exclamations left $health_mine  enemy HP")
            
            if health_mine<=0
                println("$enemy_name wins!")
                return 0
            end
        end
        round=round+1
    end
end
# Out:
# one_fight (generic function with 1 method)

# %%
outcomes = ones(100000)
 
for i in 1:100000
    outcome = one_fight(5,
    14+1+4,
    13+4+3,
    great_sword
    3,
    false,
    5,
    false,
    false,
    false,
    true,
    true,
    my_armour
    function_belegwath)
    outcomes[i] = outcome
end
 
sum(outcomes)/length(outcomes)
# Out:
# syntax: missing comma or ) in argument list
#
# Stacktrace:
#  [1] top-level scope
#    @ In[189]:10

# %%
one_fight(5,
    14+1+4,
    13+4+3,
    great_sword,
    3,
    false,
    5,
    false,
    false,
    false,
    true,
    true,
    my_armour,
    function_belegwath)
# Out:
#        kostka nr 1 wyrzuciła 3 z max 4
#        kostka nr 2 wyrzuciła 3 z max 4
#        kostka nr 3 wyrzuciła 2 z max 4
#        kostka nr 4 wyrzuciła 2 z max 4
#        kostka nr 5 wyrzuciła 4 z max 4
#        kostka nr 6 wyrzuciła 2 z max 4
#        kostka nr 7 wyrzuciła 2 z max 4
#        kostka nr 8 wyrzuciła 4 z max 4
#        kostka nr 9 wyrzuciła 3 z max 4
#        kostka nr 10 wyrzuciła 4 z max 4
#        kostka nr 11 wyrzuciła 1 z max 4
#        kostka nr 12 wyrzuciła 3 z max 4
#        kostka nr 13 wyrzuciła 3 z max 4
#        kostka nr 14 wyrzuciła 4 z max 4
#        kostka nr 15 wyrzuciła 1 z max 4
#        kostka nr 16 wyrzuciła 2 z max 4
#        kostka nr 17 wyrzuciła 4 z max 4
#        kostka nr 18 wyrzuciła 1 z max 4
#        kostka nr 19 wyrzuciła 1 z max 4
#        kostka nr 20 wyrzuciła 1 z max 4
#        kostka nr 21 wyrzuciła 2 z max 4
#        kostka nr 22 wyrzuciła 3 z max 4
#        kostka nr 23 wyrzuciła 1 z max 4
#        kostka nr 24 wyrzuciła 2 z max 4
#        kostka nr 25 wyrzuciła 2 z max 4
#        kostka nr 26 wyrzuciła 2 z max 4
#        kostka nr 27 wyrzuciła 1 z max 4
#        kostka nr 28 wyrzuciła 1 z max 4
#        kostka nr 29 wyrzuciła 1 z max 4
#        kostka nr 30 wyrzuciła 3 z max 4
#        kostka nr 31 wyrzuciła 4 z max 4
#        kostka nr 32 wyrzuciła 3 z max 4
#        kostka nr 33 wyrzuciła 4 z max 4
#        kostka nr 34 wyrzuciła 1 z max 4
#        kostka nr 35 wyrzuciła 3 z max 4
#        kostka nr 36 wyrzuciła 1 z max 4
#            suma rzutow: 84.0
#        kostka nr 1 wyrzuciła 3 z max 7
#            suma rzutow: 3.0
#        kostka nr 1 wyrzuciła 3 z max 3
#            suma rzutow: 3.0
#        kostka nr 1 wyrzuciła 2 z max 2
#            suma rzutow: 2.0
#        kostka nr 1 wyrzuciła 4 z max 4
#        kostka nr 2 wyrzuciła 1 z max 4
#        kostka nr 3 wyrzuciła 3 z max 4
#        kostka nr 4 wyrzuciła 1 z max 4
#            suma rzutow: 9.0
# [to hit 18 + 9 vs to avoid 17 + 17]
# [to hit 18 + 6 vs to avoid 17 + 14]
#    {(3+-1)d8 - 9.0}
#    {total damage 0, armour = 9.0}
#    {!total damage after armour -9.0}
# Antar hit Belegwath, Balrog of Shadow for 0.0 damage  left 84.0  enemy HP
# [to hit 22 + 16 vs to avoid 20 + 16]
#        kostka nr 1 wyrzuciła 8 z max 14
#        kostka nr 2 wyrzuciła 8 z max 14
#        kostka nr 3 wyrzuciła 14 z max 14
#            suma rzutow: 30.0
#    {(3+0.0)d14 - 9.0}
#    {total damage 30.0, armour = 9.0}
#    {!total damage after armour 21.0}
# Belegwath, Balrog of Shadow hit Antar for 21.0 damage left 28.0  enemy HP
# [to hit 18 + 16 vs to avoid 20 + 5]
#        kostka nr 1 wyrzuciła 6 z max 8
#        kostka nr 2 wyrzuciła 5 z max 8
#        kostka nr 3 wyrzuciła 4 z max 8
#        kostka nr 4 wyrzuciła 5 z max 8
#            suma rzutow: 20.0
#    {(3+1.0)d8 - 9.0}
#    {total damage 20.0, armour = 9.0}
#    {!total damage after armour 11.0}
# Belegwath, Balrog of Shadow hit Antar for 11.0 damage! left 17.0  enemy HP
#        kostka nr 1 wyrzuciła 4 z max 7
#            suma rzutow: 4.0
#        kostka nr 1 wyrzuciła 1 z max 3
#            suma rzutow: 1.0
#        kostka nr 1 wyrzuciła 2 z max 2
#            suma rzutow: 2.0
#        kostka nr 1 wyrzuciła 1 z max 4
#        kostka nr 2 wyrzuciła 1 z max 4
#        kostka nr 3 wyrzuciła 4 z max 4
#        kostka nr 4 wyrzuciła 4 z max 4
#            suma rzutow: 10.0
# [to hit 18 + 18 vs to avoid 17 + 7]
#    {(3+0.0)d8 - 10.0}
#    {total damage 24.0, armour = 10.0}
#    {!total damage after armour 14.0}
# Antar hit Belegwath, Balrog of Shadow for 14.0 damage  left 70.0  enemy HP
# [to hit 18 + 13 vs to avoid 20 + 10]
#        kostka nr 1 wyrzuciła 6 z max 8
#        kostka nr 2 wyrzuciła 6 z max 8
#        kostka nr 3 wyrzuciła 7 z max 8
#            suma rzutow: 19.0
#    {(3+0.0)d8 - 8.0}
#    {total damage 19.0, armour = 8.0}
#    {!total damage after armour 11.0}
# Belegwath, Balrog of Shadow hit Antar for 11.0 damage left 6.0  enemy HP
# [to hit 22 + 14 vs to avoid 20 + 11]
#        kostka nr 1 wyrzuciła 9 z max 14
#        kostka nr 2 wyrzuciła 11 z max 14
#        kostka nr 3 wyrzuciła 14 z max 14
#            suma rzutow: 34.0
#    {(3+0.0)d14 - 8.0}
#    {total damage 34.0, armour = 8.0}
#    {!total damage after armour 26.0}
# Belegwath, Balrog of Shadow hit Antar for 26.0 damage left -20.0  enemy HP
# Belegwath, Balrog of Shadow wins!
# 0
